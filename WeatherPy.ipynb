# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 612

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4e1a5f6fa7388c0f794df79c9a99d89e

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lasa
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | chernyshevskiy
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | anadyr
# Processing Record 6 of Set 1 | half moon bay
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | salalah
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | arvika
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | beinamar
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 1 | sao joao da barra
# Processing Record 17 of Set 1 | sohag
# Processing Record 18 of Set 1 | kalol
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | nikolskoye
# Processing Record 21 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 1 | ngaoundere
# Processing Record 23 of Set 1 | poum
# Processing Record 24 of Set 1 | tadine
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | castanos
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | caravelas
# Processing Record 30 of Set 1 | isla vista
# Processing Record 31 of Set 1 | ponta do sol
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 1 | pitogo
# Processing Record 35 of Set 1 | mount gambier
# Processing Record 36 of Set 1 | bredasdorp
# Processing Record 37 of Set 1 | faanui
# Processing Record 38 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 1 | bethel
# Processing Record 40 of Set 1 | azle
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | shalakusha
# Processing Record 43 of Set 1 | klaksvik
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | kushiro
# Processing Record 46 of Set 1 | benguela
# Processing Record 47 of Set 1 | victoria
# Processing Record 48 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 1 | hit
# Processing Record 1 of Set 2 | kibala
# Processing Record 2 of Set 2 | clyde river
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | peque
# Processing Record 5 of Set 2 | padang
# Processing Record 6 of Set 2 | albany
# Processing Record 7 of Set 2 | khor
# Processing Record 8 of Set 2 | yulara
# Processing Record 9 of Set 2 | vammala
# Processing Record 10 of Set 2 | urengoy
# Processing Record 11 of Set 2 | katsuura
# Processing Record 12 of Set 2 | crotone
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | darhan
# Processing Record 15 of Set 2 | tautira
# Processing Record 16 of Set 2 | vuktyl
# Processing Record 17 of Set 2 | vanimo
# Processing Record 18 of Set 2 | concordia
# Processing Record 19 of Set 2 | tura
# Processing Record 20 of Set 2 | saint-philippe
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | gandia
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | chara
# Processing Record 25 of Set 2 | touros
# Processing Record 26 of Set 2 | vila velha
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | guelengdeng
# City not found. Skipping...
# Processing Record 29 of Set 2 | panaba
# Processing Record 30 of Set 2 | mahebourg
# Processing Record 31 of Set 2 | vaini
# Processing Record 32 of Set 2 | kaitangata
# Processing Record 33 of Set 2 | najran
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | cayenne
# Processing Record 36 of Set 2 | husavik
# Processing Record 37 of Set 2 | yellowknife
# Processing Record 38 of Set 2 | kansk
# Processing Record 39 of Set 2 | noumea
# Processing Record 40 of Set 2 | beringovskiy
# Processing Record 41 of Set 2 | mezen
# Processing Record 42 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 43 of Set 2 | airai
# Processing Record 44 of Set 2 | port elizabeth
# Processing Record 45 of Set 2 | bull savanna
# Processing Record 46 of Set 2 | bathsheba
# Processing Record 47 of Set 2 | shahe
# Processing Record 48 of Set 2 | chapais
# Processing Record 49 of Set 2 | lagoa
# Processing Record 50 of Set 2 | busselton
# Processing Record 1 of Set 3 | meulaboh
# Processing Record 2 of Set 3 | roma
# Processing Record 3 of Set 3 | havre-saint-pierre
# Processing Record 4 of Set 3 | esperance
# Processing Record 5 of Set 3 | macusani
# Processing Record 6 of Set 3 | auki
# Processing Record 7 of Set 3 | abu samrah
# Processing Record 8 of Set 3 | butaritari
# Processing Record 9 of Set 3 | khatanga
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | constitucion
# Processing Record 12 of Set 3 | kirakira
# Processing Record 13 of Set 3 | vao
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | saint anthony
# Processing Record 16 of Set 3 | fenyi
# Processing Record 17 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 3 | deputatskiy
# Processing Record 19 of Set 3 | hermanus
# Processing Record 20 of Set 3 | naze
# Processing Record 21 of Set 3 | pouembout
# Processing Record 22 of Set 3 | beyneu
# Processing Record 23 of Set 3 | tasiilaq
# Processing Record 24 of Set 3 | shache
# Processing Record 25 of Set 3 | charapan
# Processing Record 26 of Set 3 | sorada
# Processing Record 27 of Set 3 | turgoyak
# Processing Record 28 of Set 3 | mugla
# Processing Record 29 of Set 3 | kapaa
# Processing Record 30 of Set 3 | nhulunbuy
# Processing Record 31 of Set 3 | dikson
# Processing Record 32 of Set 3 | cidreira
# Processing Record 33 of Set 3 | sitka
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | castro
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | kasongo-lunda
# Processing Record 38 of Set 3 | soma
# Processing Record 39 of Set 3 | inuvik
# Processing Record 40 of Set 3 | katangli
# Processing Record 41 of Set 3 | tuatapere
# Processing Record 42 of Set 3 | brooks
# Processing Record 43 of Set 3 | mogadishu
# Processing Record 44 of Set 3 | trairi
# Processing Record 45 of Set 3 | svetlogorsk
# Processing Record 46 of Set 3 | mapiripan
# Processing Record 47 of Set 3 | ahumada
# City not found. Skipping...
# Processing Record 48 of Set 3 | mana
# Processing Record 49 of Set 3 | igarka
# Processing Record 50 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 4 | ushtobe
# Processing Record 2 of Set 4 | dingle
# Processing Record 3 of Set 4 | port hedland
# Processing Record 4 of Set 4 | stony mountain
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | jammalamadugu
# Processing Record 7 of Set 4 | maunabo
# Processing Record 8 of Set 4 | saint-joseph
# Processing Record 9 of Set 4 | chuy
# Processing Record 10 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 4 | alofi
# Processing Record 12 of Set 4 | praia da vitoria
# Processing Record 13 of Set 4 | rawson
# Processing Record 14 of Set 4 | luderitz
# Processing Record 15 of Set 4 | fort nelson
# Processing Record 16 of Set 4 | invermere
# Processing Record 17 of Set 4 | puerto del rosario
# Processing Record 18 of Set 4 | whitianga
# Processing Record 19 of Set 4 | balimo
# City not found. Skipping...
# Processing Record 20 of Set 4 | la ronge
# Processing Record 21 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 4 | pevek
# Processing Record 23 of Set 4 | khingansk
# Processing Record 24 of Set 4 | nova olimpia
# Processing Record 25 of Set 4 | ixtapa
# Processing Record 26 of Set 4 | port augusta
# Processing Record 27 of Set 4 | picota
# Processing Record 28 of Set 4 | pimentel
# Processing Record 29 of Set 4 | skegness
# Processing Record 30 of Set 4 | east london
# Processing Record 31 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 4 | foumban
# Processing Record 33 of Set 4 | the valley
# Processing Record 34 of Set 4 | imbituba
# Processing Record 35 of Set 4 | wicklow
# Processing Record 36 of Set 4 | arcata
# Processing Record 37 of Set 4 | bengkulu
# Processing Record 38 of Set 4 | qaanaaq
# Processing Record 39 of Set 4 | fortuna
# Processing Record 40 of Set 4 | albert
# Processing Record 41 of Set 4 | grindavik
# Processing Record 42 of Set 4 | georgetown
# Processing Record 43 of Set 4 | flinders
# Processing Record 44 of Set 4 | suez
# Processing Record 45 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 46 of Set 4 | kropotkin
# Processing Record 47 of Set 4 | artyom
# Processing Record 48 of Set 4 | new norfolk
# Processing Record 49 of Set 4 | frontera
# Processing Record 50 of Set 4 | sedan
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | vegueta
# Processing Record 3 of Set 5 | bratslav
# Processing Record 4 of Set 5 | sao raimundo nonato
# Processing Record 5 of Set 5 | mahdalynivka
# Processing Record 6 of Set 5 | port macquarie
# Processing Record 7 of Set 5 | ust-maya
# Processing Record 8 of Set 5 | hilo
# Processing Record 9 of Set 5 | avarua
# Processing Record 10 of Set 5 | puerto leguizamo
# Processing Record 11 of Set 5 | honningsvag
# Processing Record 12 of Set 5 | natal
# Processing Record 13 of Set 5 | ribeira grande
# Processing Record 14 of Set 5 | port alfred
# Processing Record 15 of Set 5 | aklavik
# Processing Record 16 of Set 5 | muisne
# Processing Record 17 of Set 5 | stornoway
# Processing Record 18 of Set 5 | narsaq
# Processing Record 19 of Set 5 | margate
# Processing Record 20 of Set 5 | mehamn
# Processing Record 21 of Set 5 | yabrud
# Processing Record 22 of Set 5 | sosnovskiy
# City not found. Skipping...
# Processing Record 23 of Set 5 | bilma
# Processing Record 24 of Set 5 | dawlatabad
# Processing Record 25 of Set 5 | payakumbuh
# Processing Record 26 of Set 5 | saint-paul
# Processing Record 27 of Set 5 | port lincoln
# Processing Record 28 of Set 5 | natchez
# Processing Record 29 of Set 5 | cap malheureux
# Processing Record 30 of Set 5 | phrai bung
# City not found. Skipping...
# Processing Record 31 of Set 5 | wasilla
# Processing Record 32 of Set 5 | sao desiderio
# Processing Record 33 of Set 5 | masuguru
# Processing Record 34 of Set 5 | quang ngai
# Processing Record 35 of Set 5 | genhe
# Processing Record 36 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 5 | sept-iles
# Processing Record 38 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 39 of Set 5 | merauke
# Processing Record 40 of Set 5 | islamkot
# Processing Record 41 of Set 5 | vokhma
# Processing Record 42 of Set 5 | butte
# Processing Record 43 of Set 5 | kodiak
# Processing Record 44 of Set 5 | hofn
# Processing Record 45 of Set 5 | greensburg
# Processing Record 46 of Set 5 | gebze
# Processing Record 47 of Set 5 | bitung
# Processing Record 48 of Set 5 | la peca
# Processing Record 49 of Set 5 | ritchie
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | birigui
# Processing Record 2 of Set 6 | kahului
# Processing Record 3 of Set 6 | dwarka
# Processing Record 4 of Set 6 | puerto carreno
# Processing Record 5 of Set 6 | gbarnga
# Processing Record 6 of Set 6 | komsomolskiy
# Processing Record 7 of Set 6 | te anau
# Processing Record 8 of Set 6 | saskylakh
# Processing Record 9 of Set 6 | ulkan
# Processing Record 10 of Set 6 | avera
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | nova zagora
# Processing Record 13 of Set 6 | ayaviri
# Processing Record 14 of Set 6 | burica
# City not found. Skipping...
# Processing Record 15 of Set 6 | barabai
# Processing Record 16 of Set 6 | russell
# Processing Record 17 of Set 6 | takestan
# Processing Record 18 of Set 6 | kiunga
# Processing Record 19 of Set 6 | kununurra
# Processing Record 20 of Set 6 | ciudad bolivar
# Processing Record 21 of Set 6 | tuktoyaktuk
# Processing Record 22 of Set 6 | apollonia
# Processing Record 23 of Set 6 | salym
# Processing Record 24 of Set 6 | manaure
# Processing Record 25 of Set 6 | nanortalik
# Processing Record 26 of Set 6 | ambilobe
# Processing Record 27 of Set 6 | balakhninskiy
# Processing Record 28 of Set 6 | kargasok
# Processing Record 29 of Set 6 | gushikawa
# Processing Record 30 of Set 6 | bouna
# Processing Record 31 of Set 6 | sao sebastiao
# Processing Record 32 of Set 6 | kutum
# Processing Record 33 of Set 6 | tselinnoye
# Processing Record 34 of Set 6 | lugovskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | namibe
# Processing Record 36 of Set 6 | kuah
# Processing Record 37 of Set 6 | tonantins
# Processing Record 38 of Set 6 | cherskiy
# Processing Record 39 of Set 6 | alghero
# Processing Record 40 of Set 6 | kulhudhuffushi
# Processing Record 41 of Set 6 | bambous virieux
# Processing Record 42 of Set 6 | halden
# Processing Record 43 of Set 6 | sambava
# Processing Record 44 of Set 6 | catarama
# Processing Record 45 of Set 6 | tripoli
# Processing Record 46 of Set 6 | biskamzha
# Processing Record 47 of Set 6 | puerto madryn
# Processing Record 48 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 49 of Set 6 | byron bay
# Processing Record 50 of Set 6 | kenda
# Processing Record 1 of Set 7 | kidal
# Processing Record 2 of Set 7 | pemberton
# Processing Record 3 of Set 7 | daru
# Processing Record 4 of Set 7 | nurota
# Processing Record 5 of Set 7 | ahipara
# Processing Record 6 of Set 7 | mount pleasant
# Processing Record 7 of Set 7 | sao felix do xingu
# Processing Record 8 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 9 of Set 7 | himora
# City not found. Skipping...
# Processing Record 10 of Set 7 | ostrovnoy
# Processing Record 11 of Set 7 | azanka
# Processing Record 12 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 13 of Set 7 | tateyama
# Processing Record 14 of Set 7 | ous
# Processing Record 15 of Set 7 | pochutla
# Processing Record 16 of Set 7 | mitsamiouli
# Processing Record 17 of Set 7 | rolim de moura
# City not found. Skipping...
# Processing Record 18 of Set 7 | araouane
# Processing Record 19 of Set 7 | leningradskiy
# Processing Record 20 of Set 7 | hambantota
# Processing Record 21 of Set 7 | ibra
# Processing Record 22 of Set 7 | lorengau
# Processing Record 23 of Set 7 | riyadh
# Processing Record 24 of Set 7 | gamboula
# Processing Record 25 of Set 7 | tual
# Processing Record 26 of Set 7 | vanavara
# Processing Record 27 of Set 7 | inhambane
# Processing Record 28 of Set 7 | kachiry
# Processing Record 29 of Set 7 | linjiang
# Processing Record 30 of Set 7 | san patricio
# Processing Record 31 of Set 7 | vardo
# Processing Record 32 of Set 7 | samarai
# Processing Record 33 of Set 7 | longyearbyen
# Processing Record 34 of Set 7 | broome
# Processing Record 35 of Set 7 | kontagora
# Processing Record 36 of Set 7 | yurimaguas
# Processing Record 37 of Set 7 | qaqortoq
# Processing Record 38 of Set 7 | saryagash
# Processing Record 39 of Set 7 | harper
# Processing Record 40 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 7 | ilulissat
# Processing Record 42 of Set 7 | kruisfontein
# Processing Record 43 of Set 7 | buala
# Processing Record 44 of Set 7 | nador
# Processing Record 45 of Set 7 | beecher
# Processing Record 46 of Set 7 | general higinio morinigo
# Processing Record 47 of Set 7 | poronaysk
# Processing Record 48 of Set 7 | severo-yeniseyskiy
# Processing Record 49 of Set 7 | portland
# Processing Record 50 of Set 7 | talnakh
# Processing Record 1 of Set 8 | riviere-au-renard
# Processing Record 2 of Set 8 | bima
# Processing Record 3 of Set 8 | sola
# Processing Record 4 of Set 8 | northam
# Processing Record 5 of Set 8 | srandakan
# Processing Record 6 of Set 8 | honiara
# Processing Record 7 of Set 8 | klyuchevskiy
# Processing Record 8 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 8 | okato
# Processing Record 10 of Set 8 | sterling
# Processing Record 11 of Set 8 | hengshui
# Processing Record 12 of Set 8 | korla
# Processing Record 13 of Set 8 | hobyo
# Processing Record 14 of Set 8 | pisco
# Processing Record 15 of Set 8 | hami
# Processing Record 16 of Set 8 | omboue
# Processing Record 17 of Set 8 | limbazi
# Processing Record 18 of Set 8 | mirnyy
# Processing Record 19 of Set 8 | lincoln
# Processing Record 20 of Set 8 | humboldt
# Processing Record 21 of Set 8 | basco
# Processing Record 22 of Set 8 | impfondo
# Processing Record 23 of Set 8 | springbok
# Processing Record 24 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 25 of Set 8 | wakefield
# Processing Record 26 of Set 8 | bocas del toro
# Processing Record 27 of Set 8 | edson
# Processing Record 28 of Set 8 | hamilton
# Processing Record 29 of Set 8 | kurilsk
# Processing Record 30 of Set 8 | tiznit
# Processing Record 31 of Set 8 | covington
# Processing Record 32 of Set 8 | iqaluit
# Processing Record 33 of Set 8 | dzaoudzi
# Processing Record 34 of Set 8 | provideniya
# Processing Record 35 of Set 8 | vestmannaeyjar
# Processing Record 36 of Set 8 | torbat-e jam
# Processing Record 37 of Set 8 | luanda
# Processing Record 38 of Set 8 | pandan
# Processing Record 39 of Set 8 | yangambi
# Processing Record 40 of Set 8 | matara
# Processing Record 41 of Set 8 | les cayes
# Processing Record 42 of Set 8 | kavaratti
# Processing Record 43 of Set 8 | limbang
# Processing Record 44 of Set 8 | khorixas
# Processing Record 45 of Set 8 | bulgan
# Processing Record 46 of Set 8 | nicoya
# Processing Record 47 of Set 8 | tigil
# Processing Record 48 of Set 8 | abonnema
# Processing Record 49 of Set 8 | norman wells
# Processing Record 50 of Set 8 | ninghai
# Processing Record 1 of Set 9 | mount isa
# Processing Record 2 of Set 9 | dillon
# Processing Record 3 of Set 9 | val
# Processing Record 4 of Set 9 | lastoursville
# Processing Record 5 of Set 9 | walvis bay
# Processing Record 6 of Set 9 | xining
# Processing Record 7 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 9 | jalu
# Processing Record 10 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 11 of Set 9 | surt
# Processing Record 12 of Set 9 | coquimbo
# Processing Record 13 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 14 of Set 9 | roald
# Processing Record 15 of Set 9 | maniitsoq
# Processing Record 16 of Set 9 | volovo
# Processing Record 17 of Set 9 | lar gerd
# City not found. Skipping...
# Processing Record 18 of Set 9 | asau
# Processing Record 19 of Set 9 | qurbah
# City not found. Skipping...
# Processing Record 20 of Set 9 | cabras
# Processing Record 21 of Set 9 | zlitan
# Processing Record 22 of Set 9 | biltine
# Processing Record 23 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 24 of Set 9 | anito
# Processing Record 25 of Set 9 | aguimes
# Processing Record 26 of Set 9 | upernavik
# Processing Record 27 of Set 9 | marshall
# Processing Record 28 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 9 | tilichiki
# Processing Record 30 of Set 9 | gurupa
# Processing Record 31 of Set 9 | santa maria
# Processing Record 32 of Set 9 | plettenberg bay
# Processing Record 33 of Set 9 | vidim
# Processing Record 34 of Set 9 | waipawa
# Processing Record 35 of Set 9 | grand-santi
# Processing Record 36 of Set 9 | nancha
# Processing Record 37 of Set 9 | kasempa
# Processing Record 38 of Set 9 | antofagasta
# Processing Record 39 of Set 9 | port hardy
# Processing Record 40 of Set 9 | coahuayana
# Processing Record 41 of Set 9 | baker city
# Processing Record 42 of Set 9 | sarakhs
# Processing Record 43 of Set 9 | bowen
# Processing Record 44 of Set 9 | dingli
# Processing Record 45 of Set 9 | alice springs
# Processing Record 46 of Set 9 | barcelona
# Processing Record 47 of Set 9 | los llanos de aridane
# Processing Record 48 of Set 9 | orotukan
# Processing Record 49 of Set 9 | richards bay
# Processing Record 50 of Set 9 | smithers
# Processing Record 1 of Set 10 | taltal
# Processing Record 2 of Set 10 | general jose eduvigis diaz
# Processing Record 3 of Set 10 | sinazongwe
# Processing Record 4 of Set 10 | aljezur
# Processing Record 5 of Set 10 | doha
# Processing Record 6 of Set 10 | viravanallur
# Processing Record 7 of Set 10 | camacha
# Processing Record 8 of Set 10 | narasannapeta
# Processing Record 9 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 10 | lavrentiya
# Processing Record 11 of Set 10 | sabzevar
# Processing Record 12 of Set 10 | yining
# Processing Record 13 of Set 10 | souillac
# Processing Record 14 of Set 10 | shakawe
# Processing Record 15 of Set 10 | itarema
# Processing Record 16 of Set 10 | skelleftea
# Processing Record 17 of Set 10 | at-bashi
# Processing Record 18 of Set 10 | olavarria
# Processing Record 19 of Set 10 | ca mau
# Processing Record 20 of Set 10 | hovd
# Processing Record 21 of Set 10 | ouango
# Processing Record 22 of Set 10 | marzuq
# Processing Record 23 of Set 10 | santa rosa
# Processing Record 24 of Set 10 | astoria
# Processing Record 25 of Set 10 | isiro
# Processing Record 26 of Set 10 | maumere
# Processing Record 27 of Set 10 | rovaniemi
# Processing Record 28 of Set 10 | batagay-alyta
# Processing Record 29 of Set 10 | paamiut
# Processing Record 30 of Set 10 | tulsipur
# Processing Record 31 of Set 10 | assiniboia
# Processing Record 32 of Set 10 | pangnirtung
# Processing Record 33 of Set 10 | aktyubinskiy
# Processing Record 34 of Set 10 | muros
# Processing Record 35 of Set 10 | dhidhdhoo
# Processing Record 36 of Set 10 | urfa
# City not found. Skipping...
# Processing Record 37 of Set 10 | lazaro cardenas
# Processing Record 38 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 10 | naryan-mar
# Processing Record 40 of Set 10 | pula
# Processing Record 41 of Set 10 | baykit
# Processing Record 42 of Set 10 | kalmunai
# Processing Record 43 of Set 10 | kyren
# Processing Record 44 of Set 10 | kariba
# Processing Record 45 of Set 10 | salinopolis
# Processing Record 46 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 10 | isangel
# Processing Record 48 of Set 10 | rosarito
# Processing Record 49 of Set 10 | innisfail
# Processing Record 50 of Set 10 | manavalakurichi
# Processing Record 1 of Set 11 | grand-lahou
# Processing Record 2 of Set 11 | severomuysk
# Processing Record 3 of Set 11 | port blair
# Processing Record 4 of Set 11 | high level
# Processing Record 5 of Set 11 | simao
# Processing Record 6 of Set 11 | pechenga
# Processing Record 7 of Set 11 | rey bouba
# Processing Record 8 of Set 11 | beloha
# Processing Record 9 of Set 11 | babanusah
# City not found. Skipping...
# Processing Record 10 of Set 11 | koslan
# Processing Record 11 of Set 11 | buraydah
# Processing Record 12 of Set 11 | siloam springs
# Processing Record 13 of Set 11 | nome
# Processing Record 14 of Set 11 | vila franca do campo
# Processing Record 15 of Set 11 | baiyin
# Processing Record 16 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 17 of Set 11 | fayetteville
# Processing Record 18 of Set 11 | oistins
# Processing Record 19 of Set 11 | waiouru
# Processing Record 20 of Set 11 | antalaha
# Processing Record 21 of Set 11 | takoradi
# Processing Record 22 of Set 11 | nosy varika
# Processing Record 23 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 24 of Set 11 | bundaberg
# Processing Record 25 of Set 11 | semenivka
# Processing Record 26 of Set 11 | quatre cocos
# Processing Record 27 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 11 | tingi
# Processing Record 29 of Set 11 | labuhan
# Processing Record 30 of Set 11 | narrabri
# Processing Record 31 of Set 11 | nantucket
# Processing Record 32 of Set 11 | kushima
# Processing Record 33 of Set 11 | xai-xai
# Processing Record 34 of Set 11 | ust-karsk
# Processing Record 35 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 36 of Set 11 | weligama
# Processing Record 37 of Set 11 | nenjiang
# Processing Record 38 of Set 11 | kolarovo
# Processing Record 39 of Set 11 | purranque
# Processing Record 40 of Set 11 | zhigansk
# Processing Record 41 of Set 11 | juneau
# Processing Record 42 of Set 11 | ola
# Processing Record 43 of Set 11 | maltahohe
# Processing Record 44 of Set 11 | mokolo
# Processing Record 45 of Set 11 | sinnamary
# Processing Record 46 of Set 11 | olafsvik
# Processing Record 47 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 48 of Set 11 | yamethin
# Processing Record 49 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 50 of Set 11 | rio branco
# Processing Record 1 of Set 12 | yar-sale
# Processing Record 2 of Set 12 | panlaitan
# Processing Record 3 of Set 12 | semporna
# Processing Record 4 of Set 12 | port-de-bouc
# Processing Record 5 of Set 12 | kalas
# Processing Record 6 of Set 12 | surgut
# Processing Record 7 of Set 12 | lata
# Processing Record 8 of Set 12 | bhimunipatnam
# Processing Record 9 of Set 12 | faya
# Processing Record 10 of Set 12 | hervey bay
# Processing Record 11 of Set 12 | iquique
# Processing Record 12 of Set 12 | vestmanna
# Processing Record 13 of Set 12 | santa marinella
# Processing Record 14 of Set 12 | melbu
# Processing Record 15 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 12 | sioux lookout
# Processing Record 17 of Set 12 | oga
# Processing Record 18 of Set 12 | aswan
# Processing Record 19 of Set 12 | comodoro rivadavia
# Processing Record 20 of Set 12 | kokkola
# Processing Record 21 of Set 12 | tutoia
# Processing Record 22 of Set 12 | bumba
# Processing Record 23 of Set 12 | novonikolayevskaya
# Processing Record 24 of Set 12 | torbay
# Processing Record 25 of Set 12 | port lavaca
# Processing Record 26 of Set 12 | oshawa
# Processing Record 27 of Set 12 | veraval
# Processing Record 28 of Set 12 | mecca
# Processing Record 29 of Set 12 | okha
# Processing Record 30 of Set 12 | krasnoselkup
# Processing Record 31 of Set 12 | soldotna
# Processing Record 32 of Set 12 | mamlyutka
# Processing Record 33 of Set 12 | hargeysa
# Processing Record 34 of Set 12 | green river
# Processing Record 35 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 36 of Set 12 | bella vista
# Processing Record 37 of Set 12 | ukiah
# Processing Record 38 of Set 12 | benjamin constant
# Processing Record 39 of Set 12 | suntar
# Processing Record 40 of Set 12 | kaeo
# Processing Record 41 of Set 12 | hatillo
# Processing Record 42 of Set 12 | santiago
# Processing Record 43 of Set 12 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 12 | kitimat
# Processing Record 45 of Set 12 | aksu
# Processing Record 46 of Set 12 | amahai
# Processing Record 47 of Set 12 | tavares
# Processing Record 48 of Set 12 | kysyl-syr
# Processing Record 49 of Set 12 | yaan
# Processing Record 50 of Set 12 | bolobo
# Processing Record 1 of Set 13 | viani
# Processing Record 2 of Set 13 | sydney
# Processing Record 3 of Set 13 | uyemskiy
# Processing Record 4 of Set 13 | taoudenni
# Processing Record 5 of Set 13 | krasnozerskoye
# Processing Record 6 of Set 13 | salisbury
# Processing Record 7 of Set 13 | mabaruma
# Processing Record 8 of Set 13 | turayf
# Processing Record 9 of Set 13 | patos de minas
# Processing Record 10 of Set 13 | cabo san lucas
# Processing Record 11 of Set 13 | chicama
# Processing Record 12 of Set 13 | kuandian
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0            Lasa  46.62   10.70     44.60       100          90        8.05
# 1         Rikitea -23.12 -134.97     72.68        74         100       13.51
# 2  Chernyshevskiy  63.01  112.47     45.12        77         100        7.29
# 3       Hithadhoo  -0.60   73.08     84.42        74          93        9.17
# 4          Anadyr  64.75  177.48     26.60        73           0        4.47
# 5   Half Moon Bay  37.46 -122.43     71.01        60           5       16.11
# 6    Punta Arenas -53.15  -70.92     33.80        65         100        5.82
# 7      Chokurdakh  70.63  147.92     19.67        96          99        9.19
# 8         Salalah  17.02   54.09     82.40        83          40        2.24
# 9       Carnarvon -24.87  113.63     70.97        69          39       16.89
#
#   Country                 Date
# 0      IT  2020-05-06 01:11:58
# 1      PF  2020-05-06 01:11:58
# 2      RU  2020-05-06 01:11:58
# 3      MV  2020-05-06 01:11:38
# 4      RU  2020-05-06 01:11:59
# 5      US  2020-05-06 01:11:59
# 6      CL  2020-05-06 01:11:59
# 7      RU  2020-05-06 01:11:59
# 8      OM  2020-05-06 01:12:00
# 9      AU  2020-05-06 01:12:00

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country                 Date    Lat     Lng  Max Temp  \
# 0            Lasa      IT  2020-05-06 01:11:58  46.62   10.70     44.60
# 1         Rikitea      PF  2020-05-06 01:11:58 -23.12 -134.97     72.68
# 2  Chernyshevskiy      RU  2020-05-06 01:11:58  63.01  112.47     45.12
# 3       Hithadhoo      MV  2020-05-06 01:11:38  -0.60   73.08     84.42
# 4          Anadyr      RU  2020-05-06 01:11:59  64.75  177.48     26.60
# 5   Half Moon Bay      US  2020-05-06 01:11:59  37.46 -122.43     71.01
# 6    Punta Arenas      CL  2020-05-06 01:11:59 -53.15  -70.92     33.80
# 7      Chokurdakh      RU  2020-05-06 01:11:59  70.63  147.92     19.67
# 8         Salalah      OM  2020-05-06 01:12:00  17.02   54.09     82.40
# 9       Carnarvon      AU  2020-05-06 01:12:00 -24.87  113.63     70.97
#
#    Humidity  Cloudiness  Wind Speed
# 0       100          90        8.05
# 1        74         100       13.51
# 2        77         100        7.29
# 3        74          93        9.17
# 4        73           0        4.47
# 5        60           5       16.11
# 6        65         100        5.82
# 7        96          99        9.19
# 8        83          40        2.24
# 9        69          39       16.89

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Read the output file and store into new DataFrame.
city_data_csv_df = pd.read_csv(output_data_file)

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_csv_df["Lat"]
max_temps = city_data_csv_df["Max Temp"]
humidity = city_data_csv_df["Humidity"]
cloudiness = city_data_csv_df["Cloudiness"]
wind_speed = city_data_csv_df["Wind Speed"]

# %%
# Import the time module.
import time
# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
            humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
            cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
            wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a function to create perform linear regression on the weather data
# Plots a regression line and the equation with the data.  
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_csv_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_csv_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere for Max Temp
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for Maximum Temperature", 
                       "Max Temp", (0,0))

# %%
# Linear regression on the Southern Hemisphere for Max Temp
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Southern Hemisphere \n for Maximum Temperature", 
                       "Max Temp", (-55,90))

# %%
# Linear regression on the Northern Hemisphere for Humidity
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for % Humidity", 
                       "% Humidity", (45,10))

# %%
# Linear regression on the Southern Hemisphere for Humidity
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Southern Hemisphere \n for % Humidity", 
                       "% Humidity", (-23,22))

# %%
# Linear regression on the Northern Hemisphere for Cloudiness
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for % Cloudiness", 
                       "% Cloudiness", (0,55))

# %%
# Linear regression on the Southern Hemisphere for Cloudiness
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Southern Hemisphere \n for % Cloudiness", 
                       "% Cloudiness", (-52,25))

# %%
# Linear regression on the Northern Hemisphere for Wind Speed
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Northern Hemisphere \n for % Wind Speed", 
                       "Wind Speed", (0,50))

# %%
# Linear regression on the Southern Hemisphere for Wind Speed
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values, 
                       "Linear Regression on the Southern Hemisphere \n for Wind Speed", 
                       "Wind Speed", (-55,21))
